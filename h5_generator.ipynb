# %%
import h5py
from collections import defaultdict
import numpy as np
import os
import pandas
import pysam

sample="P01"
panel_data = "/home/dauer/projects/05.TAPESTRI_CELLCAIING/data/00.Panel/glioma_meningioma_panel/hg38/hg38_8214.amplicons"
mapped_bam="/home/dauer/projects/05.TAPESTRI_CELLCAIING/data/01.MissionBio_Portal/P01/P01.mapped.bam"
cellsavior_bam="/home/dauer/projects/05.TAPESTRI_CELLCAIING/data/03.Tapestri_Custom_CellCalling/P01/P01.cellsavior.bam"
all_barcodes_matrix="/home/dauer/projects/05.TAPESTRI_CELLCAIING/data/01.MissionBio_Portal/P01/P01.all.barcode.distribution.tsv"
cellsavior_matrix="/home/dauer/projects/05.TAPESTRI_CELLCAIING/data/03.Tapestri_Custom_CellCalling/P01/P01.cellsavior.barcode.distribution.tsv"
ad_matrix="/home/dauer/projects/05.TAPESTRI_CELLCAIING/data/04.TapVarCalling/P01/05.merged_mpileup/P01.mpileup.AD.merged.csv"
dp_matrix="/home/dauer/projects/05.TAPESTRI_CELLCAIING/data/04.TapVarCalling/P01/05.merged_mpileup/P01.mpileup.DP.merged.csv"
variants_meta = "/home/dauer/projects/05.TAPESTRI_CELLCAIING/data/04.TapVarCalling/P01/05.merged_mpileup/P01.mpileup.variants.meta.csv"
mapped_bam = pysam.AlignmentFile(mapped_bam, "rb")
cellsavior_bam = pysam.AlignmentFile(cellsavior_bam, "rb")
all_barcodes_matrix = pandas.read_csv(all_barcodes_matrix, sep="\t").set_index("barcode")
cellsavior_matrix = pandas.read_csv(cellsavior_matrix, sep="\t").set_index("cell_barcode")
ad_matrix = pandas.read_csv(ad_matrix).set_index("0")
dp_matrix = pandas.read_csv(dp_matrix).set_index("0")
N_amplicons = all_barcodes_matrix.shape[1]
all_barcodes = all_barcodes_matrix.shape[0]
cell_barcodes = cellsavior_matrix.shape[0]
N_variants = ad_matrix.shape[1]
missionbio_h5 = "/home/dauer/projects/05.TAPESTRI_CELLCAIING/data/01.MissionBio_Portal/P01/P01.dna.h5"
missionbio_h5 = h5py.File(missionbio_h5, "r")
output = "/home/dauer/output.h5"


with h5py.File(output, "w") as f:
    #creating directories
    group1_all_barcodes = f.create_group("/all_barcodes")
    group1_1_dna_read_counts = f.create_group("/all_barcodes/dna_read_counts")
    group1_1_1_ca = f.create_group("/all_barcodes/dna_read_counts/ca")
    group1_1_2_layers = f.create_group("/all_barcodes/dna_read_counts/layers")
    group1_1_3_metadata = f.create_group("/all_barcodes/dna_read_counts/metadata")
    group1_1_4_ra = f.create_group("/all_barcodes/dna_read_counts/ra")
    group2_assays = f.create_group("/assays")
    group2_1_dna_read_counts = f.create_group("/assays/dna_read_counts")
    group2_1_1_ca = f.create_group("/assays/dna_read_counts/ca")
    group2_1_2_layers = f.create_group("/assays/dna_read_counts/layers")
    group2_1_3_metadata = f.create_group("/assays/dna_read_counts/metadata")
    group2_1_4_ra = f.create_group("/assays/dna_read_counts/ra")
    group2_2_dna_variants = f.create_group("/assays/dna_variants")
    group2_2_1_ca = f.create_group("/assays/dna_variants/ca")
    group2_2_2_layers = f.create_group("/assays/dna_variants/layers")
    group2_2_3_metadata = f.create_group("/assays/dna_variants/metadata")
    group2_2_4_ra = f.create_group("/assays/dna_variants/ra")
    group3_metadata = f.create_group("/metadata")
    
    #creating datasets
    src = missionbio_h5['/all_barcodes/dna_read_counts/ca/CHROM']
    dataset1_1_1_ca_1_CHROM = f.create_dataset("/all_barcodes/dna_read_counts/ca/CHROM", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/ca/end_pos']
    dataset1_1_1_ca_2_end_pos = f.create_dataset("/all_barcodes/dna_read_counts/ca/end_pos", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/ca/id']
    dataset1_1_1_ca_3_id = f.create_dataset("/all_barcodes/dna_read_counts/ca/id", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/ca/start_pos']
    dataset1_1_1_ca_4_start_pos = f.create_dataset("/all_barcodes/dna_read_counts/ca/start_pos", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/layers/r2_read_counts']
    dataset1_1_2_layers_1_r2_read_counts = f.create_dataset("/all_barcodes/dna_read_counts/layers/r2_read_counts", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/layers/read_counts']
    dataset1_1_2_layers_2_read_counts = f.create_dataset("/all_barcodes/dna_read_counts/layers/read_counts", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/avg_mapping_error_rate']
    dataset1_1_3_metadata_1_avg_mapping_error_rate = f.create_dataset("/all_barcodes/dna_read_counts/metadata/avg_mapping_error_rate", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/avg_panel_uniformity']
    dataset1_1_3_metadata_2_avg_panel_uniformity = f.create_dataset("/all_barcodes/dna_read_counts/metadata/avg_panel_uniformity", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/avg_r1_length']
    dataset1_1_3_metadata_3_avg_r1_length = f.create_dataset("/all_barcodes/dna_read_counts/metadata/avg_r1_length", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/avg_r2_length']
    dataset1_1_3_metadata_4_avg_r2_length = f.create_dataset("/all_barcodes/dna_read_counts/metadata/avg_r2_length", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/avg_read_length']
    dataset1_1_3_metadata_5_avg_read_length = f.create_dataset("/all_barcodes/dna_read_counts/metadata/avg_read_length", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/barcode_version']
    dataset1_1_3_metadata_6_barcode_version = f.create_dataset("/all_barcodes/dna_read_counts/metadata/barcode_version", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/genome_filename']
    dataset1_1_3_metadata_7_genome_filename = f.create_dataset("/all_barcodes/dna_read_counts/metadata/genome_filename", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/genome_version']
    dataset1_1_3_metadata_8_genome_version = f.create_dataset("/all_barcodes/dna_read_counts/metadata/genome_version", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_R1_reads']
    dataset1_1_3_metadata_9_n_R1_reads = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_R1_reads", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_R2_reads']
    dataset1_1_3_metadata_10_n_R2_reads = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_R2_reads", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_amplicons']
    dataset1_1_3_metadata_11_n_amplicons = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_amplicons", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_bases_r1']
    dataset1_1_3_metadata_12_n_bases_r1 = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_bases_r1", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_bases_r1_q30']
    dataset1_1_3_metadata_13_n_bases_r1_q30 = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_bases_r1_q30", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_bases_r2']
    dataset1_1_3_metadata_14_n_bases_r2 = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_bases_r2", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_bases_r2_q30']
    dataset1_1_3_metadata_15_n_bases_r2_q30 = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_bases_r2_q30", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_cell_barcode_bases']
    dataset1_1_3_metadata_16_n_cell_barcode_bases = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_cell_barcode_bases", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_cell_barcode_bases_q30']
    dataset1_1_3_metadata_17_n_cell_barcode_bases_q30 = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_cell_barcode_bases_q30", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_cells']
    dataset1_1_3_metadata_18_n_cells = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_cells", data = len(cellsavior_matrix))
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_read_pairs']
    dataset1_1_3_metadata_19_n_read_pairs = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_read_pairs", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_read_pairs_discarded']
    dataset1_1_3_metadata_20_n_read_pairs_discarded = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_read_pairs_discarded", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_read_pairs_mapped_to_cells']
    dataset1_1_3_metadata_21_n_read_pairs_mapped_to_cells = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_read_pairs_mapped_to_cells", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_read_pairs_trimmed']
    dataset1_1_3_metadata_22_n_read_pairs_trimmed = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_read_pairs_trimmed", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_read_pairs_valid_cell_barcodes']
    dataset1_1_3_metadata_23_n_read_pairs_valid_cell_barcodes = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_read_pairs_valid_cell_barcodes", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_reads_mapped']
    dataset1_1_3_metadata_24_n_reads_mapped = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_reads_mapped", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_reads_mapped_and_paired']
    dataset1_1_3_metadata_25_n_reads_mapped_and_paired = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_reads_mapped_and_paired", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_reads_mapped_insert']
    dataset1_1_3_metadata_26_n_reads_mapped_insert = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_reads_mapped_insert", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/n_reads_properly_paired']
    dataset1_1_3_metadata_27_n_reads_properly_paired = f.create_dataset("/all_barcodes/dna_read_counts/metadata/n_reads_properly_paired", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/panel_name']
    dataset1_1_3_metadata_28_panel_name = f.create_dataset("/all_barcodes/dna_read_counts/metadata/panel_name", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/pipeline_version']
    dataset1_1_3_metadata_29_pipeline_version = f.create_dataset("/all_barcodes/dna_read_counts/metadata/pipeline_version", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/qc_bc_constant1_read_rate']
    dataset1_1_3_metadata_30_qc_bc_constant1_read_rate = f.create_dataset("/all_barcodes/dna_read_counts/metadata/qc_bc_constant1_read_rate", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/qc_bc_constant2_read_rate']
    dataset1_1_3_metadata_31_qc_bc_constant2_read_rate = f.create_dataset("/all_barcodes/dna_read_counts/metadata/qc_bc_constant2_read_rate", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/qc_gc_content']
    dataset1_1_3_metadata_32_qc_gc_content = f.create_dataset("/all_barcodes/dna_read_counts/metadata/qc_gc_content", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/qc_max_n']
    dataset1_1_3_metadata_33_qc_max_n = f.create_dataset("/all_barcodes/dna_read_counts/metadata/qc_max_n", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/qc_q30_rate']
    dataset1_1_3_metadata_34_qc_q30_rate = f.create_dataset("/all_barcodes/dna_read_counts/metadata/qc_q30_rate", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/sample_name']
    dataset1_1_3_metadata_35_sample_name = f.create_dataset("/all_barcodes/dna_read_counts/metadata/sample_name", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/metadata/selected_method']
    dataset1_1_3_metadata_36_selected_method = f.create_dataset("/all_barcodes/dna_read_counts/metadata/selected_method", data = src[...], dtype = src.dtype)
    dataset1_1_4_ra_1_assignment = f.create_dataset("/all_barcodes/dna_read_counts/ra/assignment", data = ['valid-cell' if barcode in cellsavior_matrix.index else 'invalid-barcode'for barcode in all_barcodes_matrix.index ])
    dataset1_1_4_ra_2_assignment_completeness = f.create_dataset("/all_barcodes/dna_read_counts/ra/assignment-completeness", data = ['valid-cell' if barcode in cellsavior_matrix.index else 'invalid-barcode' for barcode in all_barcodes_matrix.index])
    dataset1_1_4_ra_3_assignment_corr_umap = f.create_dataset("/all_barcodes/dna_read_counts/ra/assignment-corr_umap", data = ['valid-cell' if barcode in cellsavior_matrix.index else 'invalid-barcode' for barcode in all_barcodes_matrix.index])
    src = missionbio_h5['/all_barcodes/dna_read_counts/ra/barcode']
    dataset1_1_4_ra_4_barcode = f.create_dataset("/all_barcodes/dna_read_counts/ra/barcode", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/ra/cluster']
    dataset1_1_4_ra_5_cluster = f.create_dataset("/all_barcodes/dna_read_counts/ra/cluster", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/ra/r2']
    dataset1_1_4_ra_6_r2 = f.create_dataset("/all_barcodes/dna_read_counts/ra/r2", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/ra/sample_name']
    dataset1_1_4_ra_7_sample_name = f.create_dataset("/all_barcodes/dna_read_counts/ra/sample_name", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/ra/scaled-cov']
    dataset1_1_4_ra_8_scaled_cov = f.create_dataset("/all_barcodes/dna_read_counts/ra/scaled-cov", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/ra/umap_x']
    dataset1_1_4_ra_9_umap_x = f.create_dataset("/all_barcodes/dna_read_counts/ra/umap_x", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/all_barcodes/dna_read_counts/ra/umap_y']
    dataset1_1_4_ra_10_umap_y = f.create_dataset("/all_barcodes/dna_read_counts/ra/umap_y", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/ca/CHROM']
    dataset2_1_1_ca_1_CHROM = f.create_dataset("/assays/dna_read_counts/ca/CHROM", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/ca/end_pos']
    dataset2_1_1_ca_2_end_pos = f.create_dataset("/assays/dna_read_counts/ca/end_pos", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/ca/id']
    dataset2_1_1_ca_3_id = f.create_dataset("/assays/dna_read_counts/ca/id", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/ca/r1_counts']
    dataset2_1_1_ca_4_r1_counts = f.create_dataset("/assays/dna_read_counts/ca/r1_counts", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/ca/r2_counts']
    dataset2_1_1_ca_5_r2_counts = f.create_dataset("/assays/dna_read_counts/ca/r2_counts", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/ca/start_pos']
    dataset2_1_1_ca_6_start_pos = f.create_dataset("/assays/dna_read_counts/ca/start_pos", data = src[...], dtype = src.dtype)
    dataset2_1_2_layers_1_read_counts = f.create_dataset("/assays/dna_read_counts/layers/read_counts", data = np.array(cellsavior_matrix))
    src = missionbio_h5['/assays/dna_read_counts/metadata/avg_mapping_error_rate']
    dataset2_1_3_metadata_1_avg_mapping_error_rate = f.create_dataset("/assays/dna_read_counts/metadata/avg_mapping_error_rate", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/avg_panel_uniformity']
    dataset2_1_3_metadata_2_avg_panel_uniformity = f.create_dataset("/assays/dna_read_counts/metadata/avg_panel_uniformity", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/avg_r1_length']
    dataset2_1_3_metadata_3_avg_r1_length = f.create_dataset("/assays/dna_read_counts/metadata/avg_r1_length", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/avg_r2_length']
    dataset2_1_3_metadata_4_avg_r2_length = f.create_dataset("/assays/dna_read_counts/metadata/avg_r2_length", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/avg_read_length']
    dataset2_1_3_metadata_5_avg_read_length = f.create_dataset("/assays/dna_read_counts/metadata/avg_read_length", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/barcode_version']
    dataset2_1_3_metadata_6_barcode_version = f.create_dataset("/assays/dna_read_counts/metadata/barcode_version", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/genome_filename']
    dataset2_1_3_metadata_7_genome_filename = f.create_dataset("/assays/dna_read_counts/metadata/genome_filename", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/genome_version']
    dataset2_1_3_metadata_8_genome_version = f.create_dataset("/assays/dna_read_counts/metadata/genome_version", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/n_R1_reads']
    dataset2_1_3_metadata_9_n_R1_reads = f.create_dataset("/assays/dna_read_counts/metadata/n_R1_reads", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/n_R2_reads']
    dataset2_1_3_metadata_10_n_R2_reads = f.create_dataset("/assays/dna_read_counts/metadata/n_R2_reads", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/n_amplicons']
    dataset2_1_3_metadata_11_n_amplicons = f.create_dataset("/assays/dna_read_counts/metadata/n_amplicons", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/n_bases_r1']
    dataset2_1_3_metadata_12_n_bases_r1 = f.create_dataset("/assays/dna_read_counts/metadata/n_bases_r1", data = src[...], dtype = src.dtype)
    dataset2_1_3_metadata_13_n_bases_r1_q30 = f.create_dataset("/assays/dna_read_counts/metadata/n_bases_r1_q30", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/n_bases_r2']
    dataset2_1_3_metadata_14_n_bases_r2 = f.create_dataset("/assays/dna_read_counts/metadata/n_bases_r2", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/n_bases_r2_q30']
    dataset2_1_3_metadata_15_n_bases_r2_q30 = f.create_dataset("/assays/dna_read_counts/metadata/n_bases_r2_q30", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/n_cell_barcode_bases']
    dataset2_1_3_metadata_16_n_cell_barcode_bases = f.create_dataset("/assays/dna_read_counts/metadata/n_cell_barcode_bases", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/n_cell_barcode_bases_q30']
    dataset2_1_3_metadata_17_n_cell_barcode_bases_q30 = f.create_dataset("/assays/dna_read_counts/metadata/n_cell_barcode_bases_q30", data = src[...], dtype = src.dtype)
    dataset2_1_3_metadata_18_n_cells = f.create_dataset("/assays/dna_read_counts/metadata/n_cells", data = len(cellsavior_matrix))
    src = missionbio_h5['/assays/dna_read_counts/metadata/n_read_pairs']
    dataset2_1_3_metadata_19_n_read_pairs = f.create_dataset("/assays/dna_read_counts/metadata/n_read_pairs", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/n_read_pairs_discarded']
    dataset2_1_3_metadata_20_n_read_pairs_discarded = f.create_dataset("/assays/dna_read_counts/metadata/n_read_pairs_discarded", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/n_read_pairs_mapped_to_cells']
    dataset2_1_3_metadata_21_n_read_pairs_mapped_to_cells = f.create_dataset("/assays/dna_read_counts/metadata/n_read_pairs_mapped_to_cells", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/n_read_pairs_trimmed']
    dataset2_1_3_metadata_22_n_read_pairs_trimmed = f.create_dataset("/assays/dna_read_counts/metadata/n_read_pairs_trimmed", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/n_read_pairs_valid_cell_barcodes']
    dataset2_1_3_metadata_23_n_read_pairs_valid_cell_barcodes = f.create_dataset("/assays/dna_read_counts/metadata/n_read_pairs_valid_cell_barcodes", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/n_reads_mapped']
    dataset2_1_3_metadata_24_n_reads_mapped = f.create_dataset("/assays/dna_read_counts/metadata/n_reads_mapped", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/n_reads_mapped_and_paired']
    dataset2_1_3_metadata_25_n_reads_mapped_and_paired = f.create_dataset("/assays/dna_read_counts/metadata/n_reads_mapped_and_paired", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/n_reads_mapped_insert']
    dataset2_1_3_metadata_26_n_reads_mapped_insert = f.create_dataset("/assays/dna_read_counts/metadata/n_reads_mapped_insert", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/n_reads_properly_paired']
    dataset2_1_3_metadata_27_n_reads_properly_paired = f.create_dataset("/assays/dna_read_counts/metadata/n_reads_properly_paired", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/panel_name']
    dataset2_1_3_metadata_28_panel_name = f.create_dataset("/assays/dna_read_counts/metadata/panel_name", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/pipeline_version']
    dataset2_1_3_metadata_29_pipeline_version = f.create_dataset("/assays/dna_read_counts/metadata/pipeline_version", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/qc_bc_constant1_read_rate']
    dataset2_1_3_metadata_30_qc_bc_constant1_read_rate = f.create_dataset("/assays/dna_read_counts/metadata/qc_bc_constant1_read_rate", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/qc_bc_constant2_read_rate']
    dataset2_1_3_metadata_31_qc_bc_constant2_read_rate = f.create_dataset("/assays/dna_read_counts/metadata/qc_bc_constant2_read_rate", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/qc_gc_content']
    dataset2_1_3_metadata_32_qc_gc_content = f.create_dataset("/assays/dna_read_counts/metadata/qc_gc_content", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/qc_max_n']
    dataset2_1_3_metadata_33_qc_max_n = f.create_dataset("/assays/dna_read_counts/metadata/qc_max_n", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/qc_q30_rate']
    dataset2_1_3_metadata_34_qc_q30_rate = f.create_dataset("/assays/dna_read_counts/metadata/qc_q30_rate", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/sample_name']
    dataset2_1_3_metadata_35_sample_name = f.create_dataset("/assays/dna_read_counts/metadata/sample_name", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_read_counts/metadata/selected_method']
    dataset2_1_3_metadata_36_selected_method = f.create_dataset("/assays/dna_read_counts/metadata/selected_method", data = src[...], dtype = src.dtype)
    dataset2_1_4_ra_1_barcode = f.create_dataset("/assays/dna_read_counts/ra/barcode", data = cellsavior_matrix.index)
    src = missionbio_h5['/assays/dna_read_counts/ra/sample_name']
    dataset2_1_4_ra_2_sample_name = f.create_dataset("/assays/dna_read_counts/ra/sample_name", data = src[...], dtype = src.dtype)
    dataset2_2_1_ca_1_ALT = f.create_dataset("/assays/dna_variants/ca/ALT", data = variants_meta['ALT'])
    dataset2_2_1_ca_2_Bulk_AF = f.create_dataset("/assays/dna_variants/ca/Bulk_AF", data = variants_meta['Bulk_AF'])
    dataset2_2_1_ca_3_CHROM = f.create_dataset("/assays/dna_variants/ca/CHROM", data = variants_meta['CHROM'])
    dataset2_2_1_ca_3_POS = f.create_dataset("/assays/dna_variants/ca/POS", data = variants_meta['POS'])
    dataset2_2_1_ca_5_QUAL = f.create_dataset("/assays/dna_variants/ca/QUAL", data = variants_meta['QUAL'])
    dataset2_2_1_ca_6_REF = f.create_dataset("/assays/dna_variants/ca/REF", data = variants_meta['REF'])
    dataset2_2_1_ca_7_ado_gt_cells = f.create_dataset("/assays/dna_variants/ca/ado_gt_cells", data = variants_meta['ado_gt_cells'])
    dataset2_2_1_ca_8_ado_rate = f.create_dataset("/assays/dna_variants/ca/ado_rate", data = variants_meta['ado_rate'])
    dataset2_2_1_ca_9_amplicon = f.create_dataset("/assays/dna_variants/ca/amplicon", data = variants_meta['amplicon'])
    dataset2_2_1_ca_10_filtered = f.create_dataset("/assays/dna_variants/ca/filtered", data = [1]*len(variants_meta))
    dataset2_2_1_ca_11_id = f.create_dataset("/assays/dna_variants/ca/id", data = variants_meta['id'])
    dataset2_2_2_layers_1_AF = f.create_dataset("/assays/dna_variants/layers/AF", data = np.array(ad_matrix))
    dataset2_2_2_layers_2_DP = f.create_dataset("/assays/dna_variants/layers/DP", data = np.array(dp_matrix))
    dataset2_2_2_layers_3_FILTER_MASK = f.create_dataset("/assays/dna_variants/layers/FILTER_MASK", data = np.full(ad_matrix.shape, True, dtype=bool))
    dataset2_2_2_layers_4_GQ = f.create_dataset("/assays/dna_variants/layers/GQ", shape=(cell_barcodes,N_variants))
    dataset2_2_2_layers_5_NGT = f.create_dataset("/assays/dna_variants/layers/NGT", shape=(cell_barcodes,N_variants))
    src = missionbio_h5['/assays/dna_variants/metadata/ado_rate']
    dataset2_2_3_metadata_1_ado_rate = f.create_dataset("/assays/dna_variants/metadata/ado_rate", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/avg_mapping_error_rate']
    dataset2_2_3_metadata_2_avg_mapping_error_rate = f.create_dataset("/assays/dna_variants/metadata/avg_mapping_error_rate", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/avg_panel_uniformity']
    dataset2_2_3_metadata_3_avg_panel_uniformity = f.create_dataset("/assays/dna_variants/metadata/avg_panel_uniformity", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/avg_r1_length']
    dataset2_2_3_metadata_4_avg_r1_length = f.create_dataset("/assays/dna_variants/metadata/avg_r1_length", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/avg_r2_length']
    dataset2_2_3_metadata_5_avg_r2_length = f.create_dataset("/assays/dna_variants/metadata/avg_r2_length", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/avg_read_length']
    dataset2_2_3_metadata_6_avg_read_length = f.create_dataset("/assays/dna_variants/metadata/avg_read_length", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/barcode_version']
    dataset2_2_3_metadata_7_barcode_version = f.create_dataset("/assays/dna_variants/metadata/barcode_version", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/genome_filename']
    dataset2_2_3_metadata_8_genome_filename = f.create_dataset("/assays/dna_variants/metadata/genome_filename", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/genome_version']
    dataset2_2_3_metadata_9_genome_version = f.create_dataset("/assays/dna_variants/metadata/genome_version", data = src[...], dtype = src.dtype)
    dataset2_2_3_metadata_10_high_quality_variants = f.create_dataset("/assays/dna_variants/metadata/high_quality_variants", data = 0)
    dataset2_2_3_metadata_11_iterations = f.create_dataset("/assays/dna_variants/metadata/iterations", data = 10)
    dataset2_2_3_metadata_12_min_cell_completeness = f.create_dataset("/assays/dna_variants/metadata/min_cell_completeness", data = 50)
    dataset2_2_3_metadata_13_min_dp = f.create_dataset("/assays/dna_variants/metadata/min_dp", data = 10)
    dataset2_2_3_metadata_14_min_gq = f.create_dataset("/assays/dna_variants/metadata/min_gq", data = 30)
    dataset2_2_3_metadata_15_min_mut_prct_cells = f.create_dataset("/assays/dna_variants/metadata/min_mut_prct_cells", data = 1)
    dataset2_2_3_metadata_16_min_prct_cells = f.create_dataset("/assays/dna_variants/metadata/min_prct_cells", data = 50)
    src = missionbio_h5['/assays/dna_variants/metadata/n_R1_reads']
    dataset2_2_3_metadata_17_n_R1_reads = f.create_dataset("/assays/dna_variants/metadata/n_R1_reads", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/n_R1_reads']
    dataset2_2_3_metadata_18_n_R2_reads = f.create_dataset("/assays/dna_variants/metadata/n_R2_reads", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/n_amplicons']
    dataset2_2_3_metadata_19_n_amplicons = f.create_dataset("/assays/dna_variants/metadata/n_amplicons", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/n_bases_r1']
    dataset2_2_3_metadata_20_n_bases_r1 = f.create_dataset("/assays/dna_variants/metadata/n_bases_r1", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/n_bases_r1_q30']
    dataset2_2_3_metadata_21_n_bases_r1_q30 = f.create_dataset("/assays/dna_variants/metadata/n_bases_r1_q30", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/n_bases_r2']
    dataset2_2_3_metadata_22_n_bases_r2 = f.create_dataset("/assays/dna_variants/metadata/n_bases_r2", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/n_bases_r2_q30']
    dataset2_2_3_metadata_23_n_bases_r2_q30 = f.create_dataset("/assays/dna_variants/metadata/n_bases_r2_q30", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/n_cell_barcode_bases']
    dataset2_2_3_metadata_24_n_cell_barcode_bases = f.create_dataset("/assays/dna_variants/metadata/n_cell_barcode_bases", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/n_cell_barcode_bases_q30']
    dataset2_2_3_metadata_25_n_cell_barcode_bases_q30 = f.create_dataset("/assays/dna_variants/metadata/n_cell_barcode_bases_q30", data = src[...], dtype = src.dtype)
    dataset2_2_3_metadata_26_n_cells = f.create_dataset("/assays/dna_variants/metadata/n_cells", data = len(cellsavior_matrix))
    src = missionbio_h5['/assays/dna_variants/metadata/n_cores']
    dataset2_2_3_metadata_27_n_cores = f.create_dataset("/assays/dna_variants/metadata/n_cores", data = src[...], dtype = src.dtype)
    dataset2_2_3_metadata_28_n_passing_cells = f.create_dataset("/assays/dna_variants/metadata/n_passing_cells", data = len(cellsavior_matrix))
    dataset2_2_3_metadata_29_n_passing_variants = f.create_dataset("/assays/dna_variants/metadata/n_passing_variants", data = len(ad_matrix.index))
    src = missionbio_h5['/assays/dna_variants/metadata/n_read_pairs']
    dataset2_2_3_metadata_30_n_read_pairs = f.create_dataset("/assays/dna_variants/metadata/n_read_pairs", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/n_read_pairs_discarded']
    dataset2_2_3_metadata_31_n_read_pairs_discarded = f.create_dataset("/assays/dna_variants/metadata/n_read_pairs_discarded", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/n_read_pairs_mapped_to_cells']
    dataset2_2_3_metadata_32_n_read_pairs_mapped_to_cells = f.create_dataset("/assays/dna_variants/metadata/n_read_pairs_mapped_to_cells", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/n_read_pairs_trimmed']
    dataset2_2_3_metadata_33_n_read_pairs_trimmed = f.create_dataset("/assays/dna_variants/metadata/n_read_pairs_trimmed", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/n_read_pairs_valid_cell_barcodes']
    dataset2_2_3_metadata_34_n_read_pairs_valid_cell_barcodes = f.create_dataset("/assays/dna_variants/metadata/n_read_pairs_valid_cell_barcodes", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/n_reads_mapped']
    dataset2_2_3_metadata_35_n_reads_mapped = f.create_dataset("/assays/dna_variants/metadata/n_reads_mapped", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/n_reads_mapped_and_paired']
    dataset2_2_3_metadata_36_n_reads_mapped_and_paired = f.create_dataset("/assays/dna_variants/metadata/n_reads_mapped_and_paired", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/n_reads_mapped_insert']
    dataset2_2_3_metadata_37_n_reads_mapped_insert = f.create_dataset("/assays/dna_variants/metadata/n_reads_mapped_insert", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/n_reads_properly_paired']
    dataset2_2_3_metadata_38_n_reads_properly_paired = f.create_dataset("/assays/dna_variants/metadata/n_reads_properly_paired", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/panel_name']
    dataset2_2_3_metadata_39_panel_name = f.create_dataset("/assays/dna_variants/metadata/panel_name", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/pipeline_version']
    dataset2_2_3_metadata_40_pipeline_version = f.create_dataset("/assays/dna_variants/metadata/pipeline_version", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/qc_bc_constant1_read_rate']
    dataset2_2_3_metadata_41_qc_bc_constant1_read_rate = f.create_dataset("/assays/dna_variants/metadata/qc_bc_constant1_read_rate", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/qc_bc_constant2_read_rate']
    dataset2_2_3_metadata_42_qc_bc_constant2_read_rate = f.create_dataset("/assays/dna_variants/metadata/qc_bc_constant2_read_rate", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/qc_gc_content']
    dataset2_2_3_metadata_43_qc_gc_content = f.create_dataset("/assays/dna_variants/metadata/qc_gc_content", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/qc_max_n']
    dataset2_2_3_metadata_44_qc_max_n = f.create_dataset("/assays/dna_variants/metadata/qc_max_n", data = src[...], dtype = src.dtype)
    src = missionbio_h5['/assays/dna_variants/metadata/qc_q30_rate']
    dataset2_2_3_metadata_45_qc_q30_rate = f.create_dataset("/assays/dna_variants/metadata/qc_q30_rate", data = src[...], dtype = src.dtype)
    dataset2_2_3_metadata_46_sample_name = f.create_dataset("/assays/dna_variants/metadata/sample_name", data = sample)
    src = missionbio_h5['/assays/dna_variants/metadata/selected_method']
    dataset2_2_3_metadata_47_selected_method = f.create_dataset("/assays/dna_variants/metadata/selected_method", data = src[...], dtype = src.dtype)
    dataset2_2_3_metadata_48_vaf_het = f.create_dataset("/assays/dna_variants/metadata/vaf_het", data = 30)
    dataset2_2_3_metadata_49_vaf_hom = f.create_dataset("/assays/dna_variants/metadata/vaf_hom", data = 95)
    dataset2_2_3_metadata_50_vaf_ref = f.create_dataset("/assays/dna_variants/metadata/vaf_ref", data = 5)
    src = missionbio_h5['/assays/dna_variants/metadata/variant_caller']
    dataset2_2_3_metadata_51_variant_caller = f.create_dataset("/assays/dna_variants/metadata/variant_caller", data = src[...], dtype = src.dtype)
    dataset2_2_4_ra_1_barcode = f.create_dataset("/assays/dna_variants/ra/barcode", data = cellsavior_matrix.index)
    dataset2_2_4_ra_2_filtered = f.create_dataset("/assays/dna_variants/ra/filtered", data = [0]*len(cellsavior_matrix.index))
    dataset2_2_5_ra_3_sample_name = f.create_dataset("/assays/dna_variants/ra/sample_name", data = [sample]*len(cellsavior_matrix.index))
    import datetime
    dataset3_metadata_1_date_created = f.create_dataset("/metadata/date_created", shape=(), data = str(datetime.date.today()))
    src = missionbio_h5['/metadata/sdk_version']
    dataset3_metadata_2_sdk_version = f.create_dataset("/metadata/sdk_version", data = src[...], dtype = src.dtype)
